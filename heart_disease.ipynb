# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
df = pd.read_csv('./Heart_Disease_Prediction.csv')
df
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
# ...

# %%
X = df.drop(columns=['Heart Disease'], axis=1)
Y = df['Heart Disease']
Y
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      1
#       ..
# 265    1
# 266    1
# 267    1
# 268    1
# 269    0
# Name: Heart Disease, Length: 270, dtype: int64

# %%
plot_number = 1
plt.figure(figsize=(15,25))
columns = df.columns
for i in columns:
     if i not in ['Age', 'ST depression', 'Max HR', 'Cholesterol', 'BP']:
        plt.subplot(5, 2, plot_number)
        sns.countplot(x=i, data=df)
        plot_number = plot_number + 1

plt.show()

# %%
plot_number = 1
plt.figure(figsize=(15,25))
columns = df.columns
for i in columns:
        plt.subplot(7, 2, plot_number)
        sns.histplot(x=i, data=df)
        plot_number = plot_number + 1

plt.show()

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(), annot=True)
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_5932\4268238223.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True)

# %%
df['Heart Disease'] = df['Heart Disease'].map({'Presence': 0, 'Absence': 1})

# %%
df
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
# ...

# %%
X
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
# ...

# %%
Y
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      1
#       ..
# 265    1
# 266    1
# 267    1
# 268    1
# 269    0
# Name: Heart Disease, Length: 270, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
X_train.shape[1]
y_test
# Out:
# 30     0
# 116    0
# 79     1
# 127    1
# 196    1
# 137    0
# 209    1
# 45     1
# 158    1
# 247    1
# 183    1
# 268    1
# 227    0
# 82     0
# 165    1
# 194    1
# 226    0
# 146    0
# 104    0
# 60     1
# 221    0
# 266    1
# 46     0
# 42     1
# 185    1
# 9      0
# 22     1
# 199    0
# 109    1
# 24     1
# 113    1
# 68     1
# 144    0
# 224    1
# 252    0
# 6      0
# 120    0
# 67     0
# 119    0
# 118    1
# 25     1
# 125    1
# 244    1
# 19     1
# 77     1
# 216    1
# 90     1
# 208    0
# 93     0
# 180    1
# 15     1
# 152    1
# 232    1
# 250    0
# Name: Heart Disease, dtype: int64

# %%
# model = tf.keras.Sequential([
#     tf.keras.layers.Dense(1, input_dim=X_train.shape[1], activation='sigmoid')
# ])
model = tf.keras.Sequential([
    tf.keras.layers.Dense(14, input_dim=X_train.shape[1], activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=256, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/256
# 7/7 [==============================] - 1s 23ms/step - loss: 86.1208 - accuracy: 0.4583 - val_loss: 91.0027 - val_accuracy: 0.3889
# Epoch 2/256
# 7/7 [==============================] - 0s 5ms/step - loss: 79.3736 - accuracy: 0.4583 - val_loss: 83.4383 - val_accuracy: 0.3889
# Epoch 3/256
# 7/7 [==============================] - 0s 6ms/step - loss: 72.3285 - accuracy: 0.4583 - val_loss: 76.0086 - val_accuracy: 0.3889
# Epoch 4/256
# 7/7 [==============================] - 0s 7ms/step - loss: 65.7267 - accuracy: 0.4583 - val_loss: 68.6141 - val_accuracy: 0.3889
# Epoch 5/256
# 7/7 [==============================] - 0s 5ms/step - loss: 59.2333 - accuracy: 0.4583 - val_loss: 61.1611 - val_accuracy: 0.3889
# Epoch 6/256
# 7/7 [==============================] - 0s 5ms/step - loss: 52.3585 - accuracy: 0.4583 - val_loss: 53.6420 - val_accuracy: 0.3889
# Epoch 7/256
# ...
